# %% [markdown]
# # [파이썬 기초]

# %% [markdown]
# ## 1.파이썬 모듈

# %% [markdown]
# ##### 모듈 불러오기

# %%
# 수학 관련 함수들을 모아 놓은 "math" 모듈을 import 


# math 모듈 안에 있는 factorial() 함수를 사용(5*4*3*2*1=120)

# %% [markdown]
# ##### 모듈 내의 함수 불러 오기

# %%
# factorial() 함수만 import

# %%
# 여러 함수를 import
  

#acos: arccosine(코사인 역수), acos(1) = 코사인 -1승 = 0

# %%
# 모든 함수를 import
 

#sqrt: square root(제곱근), fabs: float absolute value(절대값)  * fabsf는 C언어에서 사용

# %%
# 함수의 이름이 길거나 어떤 필요에 의해 함수의 별명을 주고 싶은 경우는 "as 별명"으로 표현

# %% [markdown]
# ## 2.파이썬 자료형

# %% [markdown]
# ### 상수와 변수

# %% [markdown]
# ##### 상수(Constants)란? 값이 변하지 않는 숫자, 문자, 문자열과 같은 고정된 값
# - 숫자는 상수
# - 홑따옴표(‘) 혹은 쌍따옴표(“)로 표시된 문자열은 상수

# %%
# 예제1.100을 화면에 출력

# %%
# 예제2.100.123을 화면에 출력

# %%
# 예제3.안녕하세요를 화면에 출력

# %% [markdown]
# ##### 변수(Variables)란? 값을 저장하는 박스
# - 값을 저장하는 박스
# - 변수를 만든다(선언한다) = 숫자나 문자열과 같은 데이터를 저장할 수 있는 공간을 마련

# %%
# 변수의 저장과 출력

# %%
# 예제1. 변수에 값을 저장하고 출력

# %%
# 예제2. 변수에 계산식을 저장하고 출력

# %%
# 예제3. 변수에 저장하고 문자열과 함께 출력

# %%
# 예제4. 변수의 값은 변경해도 가능

# %% [markdown]
# ##### 변수명의 규칙
# - 문자 또는 언더바(_)로 시작(숫자로 시작 불가),
# - 문자, 숫자, 언더바로 구성
# - 대소문자 구분

# %%
# 예제1. 변수명 사용(영문)

# %%
# 예제2. 변수명 사용(영문+숫자)

# %%
# 예제3. 언더바(_)로 시작하는 변수명 만들기

# %% [markdown]
# ##### 변수명의 안 좋은 예
# - 파이썬은 변수 이름의 대소문자를 구분하지만 이를 이용해 변수를 구별하는 것은 좋지 않음
# - 언더바로 시작하는 변수명도 되도록 사용하지 않는 것이 좋음
# - <span style = 'color:blue'> 숫자로 시작 불가, 특수문자(&, *, (, ), %, $, #, @, !), 공백, 한글 사용 금지) </span>

# %%
# 예제1. 변수명 사용(숫자로 시작)
1000won = "천원"    # 변수명을 숫자 1000으로 시작하여 에러
print(1000won)

# %%
# 예제2. 변수명 사용(특수문자(&, *, (, ), %, $, #, @,  , ! ), 공백, 한글 사용)
email@ = test@naver.com    # 변수명에 특수문자 @를 사용하여 에러 
print(email@)

# %%
# 예제3. 변수명 사용(공백 포함)
my age = 30    # 변수명에 my와 age 사이의 공백을 사용하여 에러
print(my age)

# %% [markdown]
# ##### 니모닉 변수명(Mnemonic Variable Names)
# - mnemonic : 기억술, 기억법, 기억하는, 기억을 돕는
#    * 어원 : 그리스 로마 신화의 므네모시네(Mnemosyne)라는 기억의 신
# - 변수값과 연관 지어 변수 이름을 지정하는 것이 좋음

# %%
# 무작위로 길게 작성한 변수명은 값을 유추할 수 없음 - Worst
qwerty = 35.0 
asdfgh = 12.50
zxcvb = qwerty * asdfgh 
print(zxcvb)

# %%
# 간단한 변수명 활용시 의미를 알아보기 어려움 - Bad
a = 100 
b = 1230.5 
c = a * b 
print(c)

# %%
# 니모닉 변수명은 값의 의미를 알아보기 쉬움 - Good
day = 30 
month = 12 
year = month * day 
print(year)

# %% [markdown]
# ##### 예약어(Reserved Words)란?
# - 예약어는 파이썬이 정한 의미로만 쓰이는 특별한 단어
# - 예약어는 변수 이름이나 메소드 이름 등 다른 식별자 이름으로 사용 불가
#     - ***SyntaxError: can't assign to keyword*** >> 예약어를 변수로 사용하면 출력되는 메세지
# - 예약어는 대소문자 구별. True, False, None을 제외하고는 모두 소문자
# - 예약어 종류
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 자료형(Data type) 이해
# - 모든 프로그래밍 언어는 '자료형' 이라는 개념을 가지고 있음
# - 변수에 데이터를 입력할 때, 문자로 받을 것인지, 숫자로 받을 것인지 정한다고 생각하면 됨
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 자료형(Data type) 특징
# - 데이터의 자료형은 변수에 저장할 때 자동으로 지정됨
# - 자료형에 따라 사용할 수 있는 연산 및 함수가 달라짐
# - 자료형 확인은 type함수를 통해서 확인 가능

# %%
# 변수에 숫자형(정수) 데이터를 저장하고 type 확인

# %%
# 변수에 숫자형(실수) 데이터를 저장하고 type 확인

# %%
# 변수에 문자열 데이터를 저장하고 type 확인

# %% [markdown]
# ### 숫자형

# %% [markdown]
# ##### 숫자형(Number)이란?
# - 숫자 형태로 이루어진 자료형 : 정수(int), 실수(float), 8진수, 16진수
# - 숫자연산 : 더하기(+), 빼기(-), 곱하기(*), 나누기(/), 거듭제곱(**), 나머지(%), 몫(//)
# - 연산순서 : 괄호 → 거듭제곱 → 곱셈, 나눗셈 → 덧셈, 뺄셈 → 왼쪽에서 오른쪽

# %%
# 정수(int)를 데이터로 갖는 변수

# %%
# 실수(float)를 데이터로 갖는 변수

# %%
# 숫자연산(덧셈, 뺄셈, 곱셈, 나눗셈, 거듭제곱, 나머지, 몫)

# %%
# 연산순서에 따라 연산하기

# %%
# 예제1. 14를 3으로 나누었을 떄 몫과 나머지

# %%
# 예제2. 3의 세제곱

# %% [markdown]
# ### 문자열 자료형

# %% [markdown]
# ##### 문자열(String)이란?
# - 하나 또는 여러 개의 문자로 구성된 데이터형
# - 문자들의 앞과 뒤에 쌍따옴표(“) 또는 홑따옴표(‘)를 붙임
# - “안녕하세요.”와  ‘안녕하세요.’는 동일

# %%
# 예제1. print(“안녕하세요.”)와 print(‘안녕하세요.’) 출력하기

# %%
# 예제2. 문자열 안에 쌍 따옴표 또는 홑 따옴표 포함시켜 출력하기
test = "Python's favorite food is perl."
print(test)

test1 = '"Python is very easy." he says.'
print(test1)

test2 = 'Python\'s favorite food is perl.'
print(test2)

# %%
# 예제3. 이스케이프코드(\n) 삽입해서 여러줄 표현하기
multi = "I like python\nI need python"
print(multi)

# %%
# 예제4. 연속된 따옴표를 사용해서 여러줄 표현하기
multi='''I like python
I need python'''
print(multi)

multi="""
I like python
I need python
"""
print(multi)

# %% [markdown]
# ##### 이스케이프 코드
# - 프로그래밍할 때 사용할 수 있도록 미리 정의해 둔 “문자 조합”
# - 주로 출력물을 보기 좋게 정렬하는 용도로 사용
#
# ![image-3.png](attachment:image-3.png)

# %%
# 줄 바꿈 예시
multi = "I like python\nI need python"  
print(multi)

# %%
# 탭간격 예시
multi = "I like python\tI need python"  
print(multi)

# %%
# \그대로 표현
multi = "I like python\\I need python"  
print(multi)

# %%
# '그대로 표현
multi = "I like python \' I need python"
print(multi)

# %%
# "그대로 표현
multi = "I like python \" I need python" 
print(multi)

# %%
# 백스페이스 표현
multi = "I like python \b I need python"  
print(multi)

# %% [markdown]
# ##### 문자열 연산하기
# - 연결 연산자 : +
# - 반복 연산자 : *

# %%
# 예제1. “With”과 “POSCO” 문자열 연결하기

# %%
# 예제2. “기업시민” 5번 반복하기

# %%
# 참고. 숫자형과 문자열 더하기

# %% [markdown]
# ##### 인덱싱(Indexing)과 슬라이싱(Slicing)
# - 인덱싱 : 무엇인가를 "가리킨다"는 의미 / 표현방법 : 변수명[번호]
# - 슬라이싱 : 무엇인가를 "잘라낸다"는 의미 / 표현방법 : 변수명[시작번호:끝번호]

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
a = "Hello Python!" 	# 맨 처음 요소는 0부터 시작, 맨 뒤의 요소는 -1부터 시작

# %%
# 예제1. 세 번째 요소 추출

# %%
# 예제2. 뒤에서 다섯 번째 요소 추출

# %%
# 예제3. 네번째부터 여섯 번째까지 추출

# %%
# 예제4. 세 번째부터 끝까지 추출

# %% [markdown]
# ##### 연습문제.인덱싱과 슬라이싱

# %% [markdown]
# ##### a = "20230210Rainy", 슬라이싱을 활용하여 year, day, weather 출력하기

# %% [markdown]
# ##### a = "Python", 슬라이싱을 활용해서 Pithon으로 출력하기

# %% [markdown]
# ##### 김철수의 주민등록번호는 999999-1234567 이다. 성별을 나타내는 뒷자리의 맨 첫 번째 숫자를 출력하고, 주민등록번호를 연월일(YYYYMMDD) 부분과 그 뒤의 숫자 부분으로 나누어 출력하시오.
# ![image-2.png](attachment:image-2.png)

# %%
pin = "999999-1234567"

# %%
# split함수 사용

# %% [markdown]
# ##### 문자열 포맷팅
# - “~~ %s~~” % 변수, 문자, 숫자
# - format 함수 : “{인덱스}”.format(값) “{인덱스0} {인덱스1} .. {인덱스n}”.format(값1, 값2…값n)
# ![image-2.png](attachment:image-2.png)

# %%
# "%d" %숫자 활용

# %%
# "%s" %문자열 활용

# %%
# "%s" %변수 활용

# %%
# 국어, 영어, 수학 합계와 평균 계산하기
kor = 90
eng = 100
math = 85

# %%
# 소숫점 표현하기

# %%
# format 함수 활용한 포맷팅

# %%
# 변수 따로 지정 후 format함수 사용

# %%
# format함수에서 변수 지정

# %%
# 인덱스항목과 name = value 형태 혼용

# %%
# format함수를 활용한 포맷팅

# %%
# f 접두어 사용

# %% [markdown]
# ##### 문자열 함수
# - 길이 구하기 : len(변수명)
# - 문자 개수 세기 : 변수명.count(“문자”)
# - 위치 알려주기1 : 변수명.find(“문자”)
# - 위치 알려주기2 : 변수명.index(“문자”)
# - 문자열 삽입 : join()
# - 소문자를 대문자로 바꾸기 : 변수명.upper() ↔ 변수명.lower()
# - 공백 지우기 : lstrip(), rstrip(), strip()
# - 문자열 나누기 : 변수명.split(나누는 기준)
# - 문자열 바꾸기 :  변수명.replace(찾을값, 바꿀값, 바꿀횟수)
#     - 바꿀횟수는 생략시 모두 변경, 횟수 입력시 횟만큼만 변경

# %% [markdown]
# - 길이구하기 : len(변수명)

# %%
a = "Hello! World!"

# %% [markdown]
# - 문자 개수 세기 : 변수명.count(“문자”)

# %%
a = "Hello! World!"

# %% [markdown]
# - 위치 알려주기1 : 변수명.find(“문자”)

# %%
a = "Hello! World!"

# %% [markdown]
# - 위치 알려주기2 : 변수명.index(“문자”)

# %%
a = "Hello! World!"

# %% [markdown]
# - 문자열 삽입 : "구분자".join(리스트 or 변수)

# %%
a = "Hello! World!"

# %% [markdown]
# - 소문자/대문자/첫대문자 바꾸기 : 변수명.upper() / 변수명.lower() / 변수명.capitalize()

# %%
a = "Hello! World!"

# %% [markdown]
# - 공백 제거하기 : 변수명.lstrip(), 변수명.rstrip(), 변수명.strip()

# %%
b = "     data     "

# %% [markdown]
# - 문자열 나누기 : 변수명.split(나누는 기준)

# %%
# 공백 기준으로 나누어서 리스트로 출력하기
a = "Hello! World!"


# "-" 기준으로 나누어서 리스트로 출력하기
b = "2022-01-28"

# %% [markdown]
# - 문자열 바꾸기 :  변수명.replace(찾을값, 바꿀값, 바꿀횟수)

# %%
# 'World'문자 'Python'으로 바꾸기
a = "Hello! World!"

# %%
# 변경해야 할 횟수 지정

# %%
# 변경해야 할 횟수 미지정

# %%
# 가:나:다:라:마:바 를 ':'로 나누기
e = "가:나:다:라:마:바"

# %% [markdown]
# ### 리스트

# %% [markdown]
# ##### 리스트(list)란?
# - 여러 개의 데이터 값을 하나의 변수에 담을 수 있는 데이터 구조
# - 리스트명 = [데이터1, 데이터2, 데이터3, ... ]
#     - 데이터1, 2, ....는 숫자형, 문자열, 리스트 형태 가능
# - 인덱싱과 슬라이싱 가능
# - 중첩된 리스트 슬라이싱

# %%
test = [90, "banana", 77, [3, 4, 7, 10], "orange"] 	# 여러 유형을 데이터로 활용

# 인덱싱, 슬라이싱 하기

# %% [markdown]
# ##### 리스트생성, 연산하기
# - list()와 range() 함수 활용
# - range 함수 : range(start, stop, step)
#     - start : 시작 숫자, stop : 마지막 숫자(stop 숫자 앞까지 생성), step :  숫자의 간격(+,- 가능)
# - 연산하기 : +, *

# %%
# 예제1. num변수에 1부터 20까지 2씩 증가하는 데이터 생성

# %%
# 연산하기(+)

# %%
# 연산하기(*)

# %% [markdown]
# ##### 리스트 함수
# - 값 수정하기 : 변수명[위치] = 변경 값
# - 값 삭제하기 : del 변수명[위치]
# - 값 추가하기 : 변수명.append(값)
# - 원하는 위치에 값 추가하기 : 변수명.insert(위치, 값)
# - 확장하기 : 변수명.extend(x)  -- x는 리스트 형태 자료만 입력 가능
# - 값 제거하기 : 변수명.remove(값)
# - 값 개수 세기 : count(값)
# - 순서 뒤집기 : 변수명.reverse()
# - 리스트 정렬 : 변수명.sort() 오름차순 정렬 ↔ 변수명.sort(reverse=True)
# - 위치 반환 : 변수명.index(값)
# - ** append와 extend의 차이 : append는 1개의 값을 끝에 넣고, extend는 리스트를 추가

# %% [markdown]
# - 값 수정하기 : 변수명[위치] = 변경 값

# %%
a = [5, 7, 3, 9, 1, 2, 8, 3]

# 3번째 값 10으로 변경

# %% [markdown]
# - 값 삭제하기 : del 변수명[위치]

# %% [markdown]
# - 값 추가하기 : 변수명.append(값)

# %% [markdown]
# - 확장하기 : 변수명.extend(x)  x = list
#     - 리스트 끝에 리스트 요소 추가
#     - append는 1개의 값을 끝에 넣고, extend는 리스트를 추가하는 것이 차이점

# %% [markdown]
# - 원하는 위치에 값 추가하기 : 변수명.insert(위치, 값)

# %% [markdown]
# - 값 제거하기 : 변수명.remove(값)

# %% [markdown]
# - 값 세기 : 변수명.count(값)

# %% [markdown]
# - 순서 뒤집기 : 변수명.reverse()

# %% [markdown]
# - 리스트 정렬 : 변수명.sort() 오름차순 정렬 ↔ 변수명.sort(reverse=True)

# %%
# 오름차순
a = [5, 7, 3, 9, 1, 2, 8, 3]

# 위 결과값(정수와 리스트 혼합)의 형태 [6, 5, [5, 6], 4, 3, 8, 2, 9, 100, 10, 7] 는 정렬 에러가 발생

# %%
# 내림차순

# %% [markdown]
# - 위치 반환 : 변수명.index(값)

# %% [markdown]
# ### 튜플
#
# - 몇 가지 점을 제외하곤 리스트와 거의 비슷함
# - 튜플명 = (데이터1, 데이터2, 데이터3, ... )
#     - 데이터를 하나만 가진 경우는 데이터 뒤에 콤마(,)를 꼭 입력해야 함
# - 인덱싱과 슬라이싱 가능
# - 연산하기 : +, *
# - 리스트는 데이터 생성, 삭제, 수정이 가능하지만 튜플은 바꿀 수 없음

# %%
# 데이터가 하나인 경우에는 데이터 뒤에 콤마(,)를 꼭 입력해야 함
tp1 = (3, )
tp2 = (90, "banana", ("car", "bicycle"), (3, 4, 7, 10), "orange")

# %%
# tp2에서 3번째부터 5번째 값 직전까지 출력

# %%
# tp2 3번째 값의 0번째 값 출력

# %%
# tp1와 tp2 더하기

# %%
# tp2에 3곱하기

# %% [markdown]
# ### 연습문제. 튜플

# %% [markdown]
# ##### 튜플 (1,2,3) 에 값 4를 추가하여 (1,2,3,4)를 만들어 출력하시오.

# %% [markdown]
# ##### 변수 t = ("a", "b", "c")에서 첫 번째를 "A"로 바꾸시오.

# %%
# 따라서,

# %% [markdown]
# ### 딕셔너리 자료형

# %% [markdown]
# #### 딕셔너리(dict)란?
# - Key와 Value를 한 쌍으로 갖는 대응 관계를 나타낼 수 있는 자료형
#    - 딕셔너리명= {Key1:Value1, Key2:Value2, Key3:Value3, ...}
# - 리스트나 튜플처럼 순차적으로(sequential) 해당 요소값을 구하지 않고 Key를 통해 Value를 얻음
# - key는 중복 불가
# - Key에는 변하지 않는 값을 사용하고, Value에는 변하는 값과 변하지 않는 값 모두 사용할 수 있음

# %% [markdown]
# #### 딕셔너리 예시
# ![image-3.png](attachment:image-3.png)

# %%
# 예제 1) 아이스크림 이름과 희망가격을 딕셔너리 형태로 구성
ice = {"메로나" : 1000, "폴라포" : 1200, "빵빠레" : 1800}
print(ice)

# %%
# 예제 2) 아이스크림(죠스바, 월드콘)을 추가하시오.

# %%
# 예제 3) 메로나 가격을 출력하시오

# %% [markdown]
# #### 딕셔너리 함수

# %%
# keys() : key를 리스트로 만들기
dict = {"name" : "kim", "phone" : "010-1234-5678", "birth" : "0705"}

# %%
# values() : value를 리스트로 만들기

# %%
# items() : key, value 쌍 얻기

# %%
# get() : key로 value 얻기

# %%
# clear() : key, value 쌍 모두 지우기

# %% [markdown]
# #### 딕셔너리 요소 추가 : 변수명[key]=value

# %% [markdown]
# #### 요소삭제 : 변수명[key]=value

# %% [markdown]
# ##### 불(boolean)이란?
# - 참(True)과 거짓(False)을 나타내는 자료형(True – 참 / False – 거짓)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 변수에 True/False 지정하여 type 알아보기

# %%
# 조건문의 리턴 값 알아보기

# %% [markdown]
# - 결과값 True/False 예측하기

# %% [markdown]
# - 연산자를 활용하여 결과값 True/False 예측하기

# %%
# x in 리스트
a_list = ["line", "test", "score", "aim"]

# %%
# x not in 리스트

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 3.제어문

# %% [markdown]
# ### 입력과 출력

# %% [markdown]
# ##### input() 함수
# - 사용자에게 데이터를 입력 받기 위한 함수
# - input은 입력 받은 값을 문자열로 처리
# - 입력 받은 값을 저장하는 변수 지정 필요
# - 숫자를 입력 받아 활용 할 경우 숫자형 Type로 변환 필요

# %%
# input함수 예제

# %%
# 자료형 변환(str → int)

# %% [markdown]
# ##### ● print() 함수
# - 출력할 때 쓰는 명령어
# - 출력하고 싶은 문자나 숫자, 연산식 등을 쓴다
# - 상호작용 방식에서는 print() 명령어 사용하지 않고도 출력 가능
# - print 문을 사용하면 기본적으로 출력 후 줄이 바뀜.
#     - 줄을 바꾸지 않고 싶은 경우, end=‘ ’ 이용
# - 여러 문자열을 한 print문으로 출력할 경우,  값을 공백 또는 콤마 ‘,’ 또는 ‘+’ 기호 사용
#     - 공백으로 분리할 경우는 문자열들만 사용할 수 있으며, 출력 값 사이에 공백이 없이 출력
#     - 콤마로 분리할 경우는 숫자 값도 사용할 수 있으며 출력 값 사이에 빈 공백 하나가 출력이 됨
#     -  ‘+’ 기호는 두 문자열을 합쳐 긴 문자열을 만들 때 사용하는 연산자 / ‘+’로 여러 값들을 출력할 경우에도 문자열 값만 사용할 있음

# %%
# 줄바꿈 없이 출력

# %%
# 반복 출력

# %%
# 여러 문자열 출력

# %% [markdown]
# ### 연습문제. 입출력

# %% [markdown]
# ##### 문제1. 구매하려는 상품의 가격을 입력하고, 구매를 위해 낼 금액을 입력하면 거스름돈이 출력되도록 하세요.

# %%
# 변수 : cost(상품 가격), belong(구매를 위해 낼 금액), rest(거스름돈)

# %% [markdown]
# ##### 문제2. 국어, 영어, 수학 성적을 입력 받은 후 입력 받은 3개 과목의 평균을 계산하여 화면에 출력하시오.

# %%
# 변수 : kor(국어 성적), eng(영어 성적), math(수학 성적)

# %% [markdown]
# ### 조건문

# %% [markdown]
# ##### 조건문이란?
# - 참과 거짓을 판단하는 문장
# - if문 : 프로그래밍에서 조건을 판단하여 해당 조건에 맞는 상황을 수행
# - if문을 만들 때는 if문에 속하는 모든 문장에 들여쓰기를 해야 함

# %% [markdown]
# ```python
# if 조건1:          # if 조건문 뒤에는 반드시 콜론(:)이 붙음
#     수행할 문장1    # 들여쓰기(탭키 입력 or 스페이스바 4번)
#
# else:
#     수행할 문장2

# %% [markdown]
# ##### if문 활용
# - 조건이 참일 때

# %%
# if문 예시(1)

# %%
# if문 예시(2)

# %% [markdown]
# ##### elif문
# - 여러가지 조건을 동시에 판별할 때 사용

# %% [markdown]
# ```python
# if 조건1:
#     수행할 문장1
# elif 조건2:
#     수행할 문장2
# elif 조건3:
#     수행할 문장3
# else:
#     수행할 문장4

# %%
# elif문 예시

# %% [markdown]
# ### 연습문제. 조건문

# %% [markdown]
# ##### 키와 몸무게를 입력 받아, 비만도(BMI)를 판별하는 프로그램 만들기
# - 체질량지수(BMI) 공식 : BMI = 몸무게(kg)/(키(m) * 키(m))
#   - 저체중 : 18.5 미만
#   - 정상 : 22.9 이하
#   - 과체중 : 24.9이하
#   - 경도비만 : 29.9이하
#   - 고도비만: 30이상

# %% [markdown]
# ### 반복문

# %% [markdown]
# ##### while문이란?
# - 반복해서 문장을 수행해야 할 경우 사용하는 반복문
# - while문 : 조건문이 참인 동안에 while문 아래의 문장이 반복해서 수행

# %% [markdown]
# ```python
# while <조건문>:
#     <수행할 문장1>
#     <수행할 문장2>
#     <수행할 문장3>
#     ...
#     break

# %%
color = """1. red
2. yellow
3. blue
4. orange
Enter number: """

# %% [markdown]
# - break(while문 강제 종료)

# %%
egg = 5
money = 500

# %% [markdown]
# ##### for문이란?
# - 지정한 횟수만큼을 반복할 경우 사용하는 반복문

# %% [markdown]
# ```python
# for 변수 in 범위 :   # 범위 == 범위 또는 변수
#     <수행할 문장1>
#     <수행할 문장2>
#     ...

# %% [markdown]
# ##### for문 활용
# - 예제1. 1부터 10까지의 숫자를 더하기

# %% [markdown]
# - 예제2. 1부터 10까지 2간격으로 더하기

# %% [markdown]
# - 예제3. 60점 이상 합격, 60점 미만 불합격 메세지 출력

# %%
avers = [80, 20, 65, 50, 90]

# %% [markdown]
# - 예제4. 리스트를 사용한 for문
#
# 리스트의 첫 번째 요소인 'one'이 먼저 i변수에 대입된 후 print(i)수행
# 다음에 두번째 요소 'two'가 i변수에 대입된 후 print(i)문장을 수행하고 리스트의 마지막 요소까지 반복

# %%
test_list = ["one", "two", "three"]

# %% [markdown]
# - continue문
#  : 반복문 전체를 빠져나오는 것(break)이 아니라 해당 조건에서만 건너뛰고 싶을 경우 continue 사용

# %%
# 10이하의 홀수 출력하기

# %%
# 평균 60점 이상만 출력하기
avers = [80, 20, 65, 50, 90]

# %% [markdown]
# ### 연습문제. 반복문

# %% [markdown]
# ##### 문제1. 정수를 입력 받아 해당 수의 구구단을 출력하는 프로그램을 for문과 while문으로 각각 만들기
# - 예) 정수를 입력하시오 : 3
# - 3 x 1 = 3   3 x 2 = 6  … 3 x 9 = 27

# %%
# while문

# %%
# for문

# %% [markdown]
# ##### 문제2. for문과 if문을 이용하여, 정수를 입력 받아 정수의 약수를 구하는 프로그램 제작
# - 예) 입력 : 15    /     결과 : 1, 3, 5, 15

# %% [markdown]
# # [RPA:Robotic Process Automation]

# %% [markdown]
# ## 1.그림판에 자동으로 그림 그리기

# %% [markdown]
# - 사각형 그리기

# %% [markdown]
# - 중심으로 들어가는 사각형 그리기

# %% [markdown]
# ## 2.웹사이트 접속

# %% [markdown]
# #### 검색창 element 정보 확인/키워드 검색

# %% [markdown]
# #### 검색버튼 정보 확인/버튼 클릭

# %% [markdown]
# #### xpath 사용하기

# %% [markdown]
# - 네이버 검색
